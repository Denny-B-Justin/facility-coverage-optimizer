# %%
# %run "../facility-coverage-optimizer/extract/01a_download_worldpop"

# %%
# %run "../facility-coverage-optimizer/extract/01b_download_wb"

# %%
# %run "../facility-coverage-optimizer/extract/02_population"

# %%
# %run "../facility-coverage-optimizer/extract/03_boundaries"

# %%
# %run "../facility-coverage-optimizer/extract/04_facilities"

# %%
# %run "../facility-coverage-optimizer/transform/01_prepare"

# %%
# %run "../facility-coverage-optimizer/transform/02_coverage"

# %%
# %run "../facility-coverage-optimizer/transform/03_optimize"

# %%
print("=== DONE ===")
